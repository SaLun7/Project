# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\KDS-22\Desktop\Project\data\raw\03_독거노인_현황_연령별.xlsx", header= 1)

print(df.head())
# Out:
#    구별(1)  구별(2)     합계    합계.1    합계.2 국민기초생활보장 수급권자 국민기초생활보장 수급권자.1  \
# 0  구별(1)  구별(2)      계  65~79세  80세 이상             계          65~79세
# 1     합계     소계  17752   12828    4924          3253            2238
# 2    동남구     소계   9597    6821    2776          1728            1176
# 3    NaN    목천읍   1135     750     385           201             130
# 4    NaN    풍세면    348     217     131            35              23
#
#   국민기초생활보장 수급권자.2 저소득노인 저소득노인.1 저소득노인.2     일반    일반.1    일반.2
# 0          80세 이상     계  65~79세  80세 이상      계  65~79세  80세 이상
# 1            1015  1071     494     577  13428   10096    3332
# 2             552   675     309     366   7194    5336    1858
# 3              71    68      26      42    866     594     272
# 4              12    37      11      26    276     183      93
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   구별(1)            4 non-null      str
#  1   구별(2)            34 non-null     str
#  2   합계               34 non-null     object
#  3   합계.1             34 non-null     object
#  4   합계.2             34 non-null     object
#  5   국민기초생활보장 수급권자    34 non-null     object
#  6   국민기초생활보장 수급권자.1  34 non-null     object
#  7   국민기초생활보장 수급권자.2  34 non-null     object
#  8   저소득노인            34 non-null     object
#  9   저소득노인.1          34 non-null     object
#  10  저소득노인.2          34 non-null     object
#  11  일반               34 non-null     object
#  12  일반.1             34 non-null     object
#  13  일반.2             34 non-null     object
# dtypes: object(12), str(2)
# memory usage: 3.8+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# 구별(1)              30
# 구별(2)               0
# 합계                  0
# 합계.1                0
# 합계.2                0
# 국민기초생활보장 수급권자       0
# 국민기초생활보장 수급권자.1     0
# 국민기초생활보장 수급권자.2     0
# 저소득노인               0
# 저소득노인.1             0
# 저소득노인.2             0
# 일반                  0
# 일반.1                0
# 일반.2                0
# dtype: int64
